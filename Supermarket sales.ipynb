# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("supermarket_sales.csv")

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df=df.drop("Invoice ID",axis=1)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   object
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Branch                   1000 non-null   object
#  1   City                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   datetime64[ns]
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  cogs                     1000 non-null   float64
# ...

# %%
df['Month']=df['Date'].dt.month

# %%
df['Year']=df['Date'].dt.year

# %%
df['Day']=df['Date'].dt.day

# %%
df=df.drop("Date",axis=1)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total   Time      Payment    cogs  \
# 0         74.69         7  26.1415   548.9715  13:08      Ewallet  522.83
# ...

# %%
sns.boxplot(df['Quantity'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Quantity'>

# %%
sns.boxplot(df['Unit price'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Unit price'>

# %%
sns.boxplot(df['Tax 5%'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tax 5%'>

# %%
q1=df['Tax 5%'].quantile(0.25)

# %%
q3=df['Tax 5%'].quantile(0.75)

# %%
IQR=q3-q1

# %%
lower=q1-1.5*IQR

# %%
upper=q3+1.5*IQR

# %%
df=df[(df['Tax 5%']>lower) & (df['Tax 5%']<upper)]

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total   Time      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715  13:08      Ewallet  522.83
# ...

# %%
sns.boxplot(df['Total'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Total'>

# %%
sns.boxplot(df['cogs'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cogs'>

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total   Time      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715  13:08      Ewallet  522.83
# ...

# %%
sns.boxplot(df['gross margin percentage'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gross margin percentage'>

# %%
sns.boxplot(df['gross income'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gross income'>

# %%
sns.boxplot(df['Rating'])
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rating'>

# %%
df['Hour']=pd.to_datetime(df['Time'],format="%H:%M").dt.hour
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24484\2777376628.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour']=pd.to_datetime(df['Time'],format="%H:%M").dt.hour

# %%
df['Minute']=pd.to_datetime(df['Time'],format="%H:%M").dt.minute
# Out:
# C:\Users\himanshu\AppData\Local\Temp\ipykernel_24484\3249288647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute']=pd.to_datetime(df['Time'],format="%H:%M").dt.minute

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total   Time      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715  13:08      Ewallet  522.83
# ...

# %%
df=df.drop("Time",axis=1)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
sns.countplot(x=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
df.groupby("Gender").size()
# Out:
# Gender
# Female    495
# Male      496
# dtype: int64

# %% [markdown]
# # Observation :
# 1. Male and female do shopping equally

# %%
sns.countplot(x=df['Gender'],hue=df['Customer type'])
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
df.groupby("Gender")['Customer type'].value_counts().sort_values(ascending=False)
# Out:
# Gender  Customer type
# Female  Member           258
# Male    Normal           256
#         Member           240
# Female  Normal           237
# Name: Customer type, dtype: int64

# %% [markdown]
# # Observation :
# 1. Female member customers do maximum shopping.
# 2. Female normal customers do minimum shopping.

# %%
sns.countplot(x=df['Product line'])
plt.xticks(rotation=90)
plt.show()

# %%
df.groupby("Product line").size().sort_values(ascending=False)
# Out:
# Product line
# Fashion accessories       175
# Food and beverages        173
# Electronic accessories    170
# Sports and travel         165
# Home and lifestyle        156
# Health and beauty         152
# dtype: int64

# %% [markdown]
# # Observations:
# 1. People do more shopping for Fashion accessories and least shopping for Health and beauty

# %%
sns.countplot(df['Hour'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.groupby("Hour").size().sort_values(ascending=False)
# Out:
# Hour
# 19    113
# 15    102
# 10    101
# 13     99
# 18     93
# 11     90
# 12     89
# 14     82
# 16     75
# 20     74
# 17     73
# dtype: int64

# %% [markdown]
# # Observations:
# 1. People do more shopping at 19 hour and less shopping at 17

# %%
plt.figure(figsize=(15,10))
sns.countplot(df['Day'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.groupby("Day").size().sort_values(ascending=False)
# Out:
# Day
# 25    42
# 15    42
# 19    41
# 5     41
# 26    39
# 2     39
# 14    39
# 8     39
# 27    38
# 7     38
# 23    36
# 9     36
# 3     36
# 20    35
# 6     33
# 24    33
# 10    32
# 12    30
# 17    30
# 28    30
# 4     29
# 1     28
# 22    28
# 13    28
# 11    27
# 16    26
# 18    23
# 21    20
# 29    20
# 30    19
# 31    14
# dtype: int64

# %% [markdown]
# # Observations:
# 1. People do more shopping on 25 th Day of Month and least shopping on 31 st Day of Month

# %%
sns.countplot(df['Month'])
plt.show()
# Out:
# C:\Users\himanshu\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Month'].value_counts()
# Out:
# 1    347
# 3    344
# 2    300
# Name: Month, dtype: int64

# %% [markdown]
# # Observations:
# 1. People do more shopping on Month 1
# 2. People do less shopping on Month 2

# %%
sns.countplot(x=df['Branch'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
df.groupby("Branch").size()
# Out:
# Branch
# A    339
# B    330
# C    322
# dtype: int64

# %% [markdown]
# # Observations:
# 1. People do more shopping at Branch A
# 2. People do less shopping at branch C

# %%
sns.countplot(x=df['Payment'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
df.groupby("Payment").size()
# Out:
# Payment
# Cash           342
# Credit card    307
# Ewallet        342
# dtype: int64

# %% [markdown]
# # Observations:
# 1. People do more payments from Ewallet
# 2. People do less payments from Credit card

# %%
sns.countplot(x=df['City'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='count'>

# %%
df.groupby("City").size().sort_values(ascending=False)
# Out:
# City
# Yangon       339
# Mandalay     330
# Naypyitaw    322
# dtype: int64

# %% [markdown]
# # Observations:
# 1. People do more shopping from Yangon
# 2. People do less shopping from Naypyitaw

# %%
sns.countplot(x=df['Customer type'])
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='count'>

# %%
df.groupby("Customer type").size()
# Out:
# Customer type
# Member    498
# Normal    493
# dtype: int64

# %% [markdown]
# # Observations:
# 1. Customer type Member do more shopping.
# 2. Customer type Normal do less shopping.

# %%
sns.barplot(x=df['Branch'],y=df['gross income'],hue=df['Month'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %%
df.groupby(["Branch","Month"])['gross income'].mean().sort_values(ascending=False)
# Out:
# Branch  Month
# C       3        16.711160
# B       1        15.650941
# A       1        15.478643
# B       2        15.039000
# C       2        15.000791
# A       2        14.757210
# C       1        14.677466
# B       3        14.403626
# A       3        14.120406
# Name: gross income, dtype: float64

# %% [markdown]
# # Observations:
# 1. Branch C in month 3 has the highest gross income
# 2. Branch A in month 3 has the lowest gross income

# %%
sns.barplot(x=df['Branch'],y=df['Rating'],hue=df['Gender'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %%
gender_spend_df=df[['City','Gender','Product line','Total']]

# %%
gender_spend_df
# Out:
#           City  Gender            Product line     Total
# 0       Yangon  Female       Health and beauty  548.9715
# 1    Naypyitaw  Female  Electronic accessories   80.2200
# 2       Yangon    Male      Home and lifestyle  340.5255
# 3       Yangon    Male       Health and beauty  489.0480
# 4       Yangon    Male       Sports and travel  634.3785
# ..         ...     ...                     ...       ...
# 994  Naypyitaw  Female  Electronic accessories   63.9975
# 995  Naypyitaw    Male       Health and beauty   42.3675
# 997     Yangon    Male      Food and beverages   33.4320
# 998     Yangon    Male      Home and lifestyle   69.1110
# 999     Yangon  Female     Fashion accessories  649.2990
#
# [991 rows x 4 columns]

# %%
female_spend_df=gender_spend_df[gender_spend_df['Gender']=="Female"]

# %%
female_spend_df
# Out:
#           City  Gender            Product line     Total
# 0       Yangon  Female       Health and beauty  548.9715
# 1    Naypyitaw  Female  Electronic accessories   80.2200
# 6       Yangon  Female  Electronic accessories  433.6920
# 7    Naypyitaw  Female      Home and lifestyle  772.3800
# 8       Yangon  Female       Health and beauty   76.1460
# ..         ...     ...                     ...       ...
# 986   Mandalay  Female       Health and beauty   30.9960
# 990     Yangon  Female      Food and beverages  296.9400
# 991   Mandalay  Female       Sports and travel  804.3000
# 994  Naypyitaw  Female  Electronic accessories   63.9975
# 999     Yangon  Female     Fashion accessories  649.2990
#
# [495 rows x 4 columns]

# %%
female_spend_df=female_spend_df.reset_index(drop=True)

# %%
female_spend_df
# Out:
#           City  Gender            Product line     Total
# 0       Yangon  Female       Health and beauty  548.9715
# 1    Naypyitaw  Female  Electronic accessories   80.2200
# 2       Yangon  Female  Electronic accessories  433.6920
# 3    Naypyitaw  Female      Home and lifestyle  772.3800
# 4       Yangon  Female       Health and beauty   76.1460
# ..         ...     ...                     ...       ...
# 490   Mandalay  Female       Health and beauty   30.9960
# 491     Yangon  Female      Food and beverages  296.9400
# 492   Mandalay  Female       Sports and travel  804.3000
# 493  Naypyitaw  Female  Electronic accessories   63.9975
# 494     Yangon  Female     Fashion accessories  649.2990
#
# [495 rows x 4 columns]

# %%
female_spend_df=female_spend_df.sort_values(by="Total",ascending=False)

# %%
female_spend_df
# Out:
#           City  Gender            Product line     Total
# 205     Yangon  Female      Home and lifestyle  951.8250
# 70   Naypyitaw  Female       Sports and travel  942.9000
# 96    Mandalay  Female  Electronic accessories  942.4485
# 296  Naypyitaw  Female      Food and beverages  935.2665
# 478     Yangon  Female      Food and beverages  932.3370
# ..         ...     ...                     ...       ...
# 396   Mandalay  Female       Health and beauty   18.6375
# 479     Yangon  Female     Fashion accessories   16.2750
# 129     Yangon  Female       Sports and travel   16.1070
# 102  Naypyitaw  Female     Fashion accessories   13.1670
# 304     Yangon  Female     Fashion accessories   12.6945
#
# [495 rows x 4 columns]

# %%
sns.barplot(x=female_spend_df['Product line'],y=female_spend_df['Total'])
plt.xticks(rotation=90)
plt.show()

# %%
female_spend_df.groupby("Product line")['Total'].mean().sort_values(ascending=False)
# Out:
# Product line
# Home and lifestyle        363.532500
# Food and beverages        361.083792
# Electronic accessories    322.643125
# Sports and travel         316.926448
# Fashion accessories       301.851543
# Health and beauty         290.015414
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Female spend mostly of the money on Home and lifestyle and least money on Health and beauty

# %%
gender_spend_df
# Out:
#           City  Gender            Product line     Total
# 0       Yangon  Female       Health and beauty  548.9715
# 1    Naypyitaw  Female  Electronic accessories   80.2200
# 2       Yangon    Male      Home and lifestyle  340.5255
# 3       Yangon    Male       Health and beauty  489.0480
# 4       Yangon    Male       Sports and travel  634.3785
# ..         ...     ...                     ...       ...
# 994  Naypyitaw  Female  Electronic accessories   63.9975
# 995  Naypyitaw    Male       Health and beauty   42.3675
# 997     Yangon    Male      Food and beverages   33.4320
# 998     Yangon    Male      Home and lifestyle   69.1110
# 999     Yangon  Female     Fashion accessories  649.2990
#
# [991 rows x 4 columns]

# %%
male_spend_df=gender_spend_df[gender_spend_df['Gender']=="Male"]

# %%
male_spend_df
# Out:
#           City Gender            Product line     Total
# 2       Yangon   Male      Home and lifestyle  340.5255
# 3       Yangon   Male       Health and beauty  489.0480
# 4       Yangon   Male       Sports and travel  634.3785
# 5    Naypyitaw   Male  Electronic accessories  627.6165
# 11    Mandalay   Male  Electronic accessories  107.1420
# ..         ...    ...                     ...       ...
# 992     Yangon   Male  Electronic accessories  121.8630
# 993   Mandalay   Male     Fashion accessories  183.6450
# 995  Naypyitaw   Male       Health and beauty   42.3675
# 997     Yangon   Male      Food and beverages   33.4320
# 998     Yangon   Male      Home and lifestyle   69.1110
#
# [496 rows x 4 columns]

# %%
male_spend_df=male_spend_df.reset_index(drop=True)

# %%
male_spend_df
# Out:
#           City Gender            Product line     Total
# 0       Yangon   Male      Home and lifestyle  340.5255
# 1       Yangon   Male       Health and beauty  489.0480
# 2       Yangon   Male       Sports and travel  634.3785
# 3    Naypyitaw   Male  Electronic accessories  627.6165
# 4     Mandalay   Male  Electronic accessories  107.1420
# ..         ...    ...                     ...       ...
# 491     Yangon   Male  Electronic accessories  121.8630
# 492   Mandalay   Male     Fashion accessories  183.6450
# 493  Naypyitaw   Male       Health and beauty   42.3675
# 494     Yangon   Male      Food and beverages   33.4320
# 495     Yangon   Male      Home and lifestyle   69.1110
#
# [496 rows x 4 columns]

# %%
male_spend_df=male_spend_df.sort_values(by="Total",ascending=False)

# %%
male_spend_df
# Out:
#           City Gender         Product line     Total
# 70   Naypyitaw   Male    Health and beauty  950.2500
# 64    Mandalay   Male    Sports and travel  944.6220
# 463  Naypyitaw   Male  Fashion accessories  943.2990
# 36   Naypyitaw   Male   Food and beverages  939.5400
# 222  Naypyitaw   Male    Sports and travel  937.8180
# ..         ...    ...                  ...       ...
# 215  Naypyitaw   Male  Fashion accessories   17.0940
# 26   Naypyitaw   Male  Fashion accessories   16.2015
# 206  Naypyitaw   Male   Home and lifestyle   14.6790
# 227  Naypyitaw   Male  Fashion accessories   13.4190
# 410  Naypyitaw   Male    Sports and travel   10.6785
#
# [496 rows x 4 columns]

# %%
sns.barplot(x=male_spend_df['Product line'],y=male_spend_df['Total'])
plt.xticks(rotation=90)
plt.show()

# %%
male_spend_df.groupby("Product line")['Total'].mean().sort_values(ascending=False)
# Out:
# Product line
# Health and beauty         348.099460
# Sports and travel         340.360327
# Electronic accessories    316.691965
# Fashion accessories       281.842037
# Home and lifestyle        275.920196
# Food and beverages        273.499125
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Male spend mostly of the money on Health and beauty and least money on Food and beverages

# %% [markdown]
# # Payment

# %%
gender_spend_df=df[['Customer type','Gender','Payment','Total']]

# %%
gender_spend_df
# Out:
#     Customer type  Gender      Payment     Total
# 0          Member  Female      Ewallet  548.9715
# 1          Normal  Female         Cash   80.2200
# 2          Normal    Male  Credit card  340.5255
# 3          Member    Male      Ewallet  489.0480
# 4          Normal    Male      Ewallet  634.3785
# ..            ...     ...          ...       ...
# 994        Member  Female      Ewallet   63.9975
# 995        Normal    Male      Ewallet   42.3675
# 997        Member    Male         Cash   33.4320
# 998        Normal    Male         Cash   69.1110
# 999        Member  Female         Cash  649.2990
#
# [991 rows x 4 columns]

# %%
female_spend_df=gender_spend_df[gender_spend_df['Gender']=="Female"]

# %%
female_spend_df
# Out:
#     Customer type  Gender      Payment     Total
# 0          Member  Female      Ewallet  548.9715
# 1          Normal  Female         Cash   80.2200
# 6          Member  Female      Ewallet  433.6920
# 7          Normal  Female      Ewallet  772.3800
# 8          Member  Female  Credit card   76.1460
# ..            ...     ...          ...       ...
# 986        Normal  Female      Ewallet   30.9960
# 990        Normal  Female  Credit card  296.9400
# 991        Normal  Female      Ewallet  804.3000
# 994        Member  Female      Ewallet   63.9975
# 999        Member  Female         Cash  649.2990
#
# [495 rows x 4 columns]

# %%
sns.countplot(x=female_spend_df['Payment'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
female_spend_df.groupby("Payment").size()
# Out:
# Payment
# Cash           177
# Credit card    160
# Ewallet        158
# dtype: int64

# %% [markdown]
# # Observation :
# 1. Female customers do maximum cash payments and minimum Ewallet payments

# %%
sns.countplot(x=female_spend_df['Payment'],hue=female_spend_df['Customer type'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
female_spend_df.groupby(["Payment","Customer type"]).size().sort_values(ascending=False)
# Out:
# Payment      Customer type
# Cash         Member           90
# Credit card  Member           88
# Cash         Normal           87
# Ewallet      Member           80
#              Normal           78
# Credit card  Normal           72
# dtype: int64

# %% [markdown]
# # Observation :
# 1. Maximum cash,credit card and Ewallet payments are done by female customers having membership.

# %%
sns.barplot(x=female_spend_df['Payment'],y=female_spend_df['Total'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
female_spend_df.groupby('Payment')['Total'].mean().sort_values()
# Out:
# Payment
# Credit card    315.079406
# Cash           330.576780
# Ewallet        334.261519
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maximum average payments done by female customers using Ewallet.
# 2. Minimum average payments done by female customers using Credit card.

# %%
sns.barplot(x=female_spend_df['Payment'],y=female_spend_df['Total'],hue=female_spend_df['Customer type'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
female_spend_df.groupby(["Payment","Customer type"])['Total'].mean().sort_values(ascending=False)
# Out:
# Payment      Customer type
# Ewallet      Normal           341.264404
# Cash         Member           332.381467
# Credit card  Member           328.864773
# Cash         Normal           328.709862
# Ewallet      Member           327.433706
# Credit card  Normal           298.230625
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Normal female customers spend maximum average money using Ewallet.
# 2. Normal female customers spend minimum average money using Credit card.

# %%
male_spend_df=gender_spend_df[gender_spend_df['Gender']=="Male"]

# %%
male_spend_df
# Out:
#     Customer type Gender      Payment     Total
# 2          Normal   Male  Credit card  340.5255
# 3          Member   Male      Ewallet  489.0480
# 4          Normal   Male      Ewallet  634.3785
# 5          Normal   Male      Ewallet  627.6165
# 11         Member   Male         Cash  107.1420
# ..            ...    ...          ...       ...
# 992        Normal   Male      Ewallet  121.8630
# 993        Normal   Male      Ewallet  183.6450
# 995        Normal   Male      Ewallet   42.3675
# 997        Member   Male         Cash   33.4320
# 998        Normal   Male         Cash   69.1110
#
# [496 rows x 4 columns]

# %%
sns.countplot(x=male_spend_df['Payment'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
male_spend_df.groupby("Payment").size().sort_values(ascending=False)
# Out:
# Payment
# Ewallet        184
# Cash           165
# Credit card    147
# dtype: int64

# %% [markdown]
# # Observation :
# 1. Maximum payment done by male Customers using Ewallet.
# 2. Minimum payment done by male Customers using Credit Card.

# %%
sns.countplot(x=male_spend_df['Payment'],hue=male_spend_df['Customer type'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
male_spend_df.groupby(["Payment","Customer type"]).size().sort_values(ascending=False)
# Out:
# Payment      Customer type
# Ewallet      Normal           104
# Cash         Normal            87
# Credit card  Member            82
# Ewallet      Member            80
# Cash         Member            78
# Credit card  Normal            65
# dtype: int64

# %% [markdown]
# # Observation :
# 1. Maximum payment done by Normal Male customer using EWallet
# 2. Minimum payment done by Normal Male customer using Credit Card.

# %%
sns.barplot(x=male_spend_df['Payment'],y=male_spend_df['Total'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
male_spend_df.groupby("Payment")['Total'].mean()
# Out:
# Payment
# Cash           313.265273
# Credit card    314.485286
# Ewallet        294.016777
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maximum average payments done by male customer using Credit Card.
# 2. Minimum average payments done by male customer using Ewallet.

# %%
sns.barplot(x=male_spend_df['Payment'],y=male_spend_df['Total'],hue=male_spend_df['Customer type'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
male_spend_df.groupby(["Payment","Customer type"])['Total'].mean().sort_values(ascending=False)
# Out:
# Payment      Customer type
# Credit card  Member           326.439238
# Cash         Member           317.265173
#              Normal           309.679155
# Ewallet      Member           307.022494
# Credit card  Normal           299.404915
# Ewallet      Normal           284.012380
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maximum average payments are done by  male member customer using credit card.
# 2. Minimum average payments are done by normal male customer using Ewallet.

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
new_df=df[['Branch','City','Rating','gross income']]

# %%
new_df
# Out:
#     Branch       City  Rating  gross income
# 0        A     Yangon     9.1       26.1415
# 1        C  Naypyitaw     9.6        3.8200
# 2        A     Yangon     7.4       16.2155
# 3        A     Yangon     8.4       23.2880
# 4        A     Yangon     5.3       30.2085
# ..     ...        ...     ...           ...
# 994      C  Naypyitaw     5.9        3.0475
# 995      C  Naypyitaw     6.2        2.0175
# 997      A     Yangon     7.7        1.5920
# 998      A     Yangon     4.1        3.2910
# 999      A     Yangon     6.6       30.9190
#
# [991 rows x 4 columns]

# %%
sns.barplot(x=new_df['Branch'],y=df['gross income'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='gross income'>

# %%
new_df.groupby("Branch")['gross income'].mean()
# Out:
# Branch
# A    14.771889
# B    15.029264
# C    15.445346
# Name: gross income, dtype: float64

# %%
sns.barplot(x=new_df['Branch'],y=df['Rating'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %%
sns.barplot(x=new_df['Branch'],y=df['Rating'],hue=new_df['City'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
new_df=df[['Branch','City','Product line','Unit price','Quantity','Tax 5%','Total']]

# %%
new_df
# Out:
#     Branch       City            Product line  Unit price  Quantity   Tax 5%  \
# 0        A     Yangon       Health and beauty       74.69         7  26.1415
# 1        C  Naypyitaw  Electronic accessories       15.28         5   3.8200
# 2        A     Yangon      Home and lifestyle       46.33         7  16.2155
# 3        A     Yangon       Health and beauty       58.22         8  23.2880
# 4        A     Yangon       Sports and travel       86.31         7  30.2085
# ..     ...        ...                     ...         ...       ...      ...
# 994      C  Naypyitaw  Electronic accessories       60.95         1   3.0475
# 995      C  Naypyitaw       Health and beauty       40.35         1   2.0175
# 997      A     Yangon      Food and beverages       31.84         1   1.5920
# 998      A     Yangon      Home and lifestyle       65.82         1   3.2910
# 999      A     Yangon     Fashion accessories       88.34         7  30.9190
#
#         Total
# 0    548.9715
# ...

# %%
product_df=new_df[new_df['Product line']=="Sports and travel"]

# %%
product_df
# Out:
#     Branch      City       Product line  Unit price  Quantity   Tax 5%  \
# 4        A    Yangon  Sports and travel       86.31         7  30.2085
# 15       B  Mandalay  Sports and travel       93.72         6  28.1160
# 17       A    Yangon  Sports and travel       72.61         6  21.7830
# 24       A    Yangon  Sports and travel       88.63         3  13.2945
# 31       B  Mandalay  Sports and travel       78.07         9  35.1315
# ..     ...       ...                ...         ...       ...      ...
# 926      B  Mandalay  Sports and travel       88.31         1   4.4155
# 929      B  Mandalay  Sports and travel       25.31         2   2.5310
# 937      A    Yangon  Sports and travel       89.48         5  22.3700
# 982      A    Yangon  Sports and travel       97.48         9  43.8660
# 991      B  Mandalay  Sports and travel       76.60        10  38.3000
#
#         Total
# 4    634.3785
# 15   590.4360
# 17   457.4430
# 24   279.1845
# 31   737.7615
# ..        ...
# ...

# %%
sns.barplot(x=product_df['Branch'],y=product_df['Total'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %%
sns.barplot(x=product_df['City'],y=product_df['Total'])
# Out:
# <AxesSubplot:xlabel='City', ylabel='Total'>

# %%
product_df.groupby("City")['Total'].mean().sort_values(ascending=False)
# Out:
# City
# Naypyitaw    335.450182
# Yangon       328.350839
# Mandalay     322.390306
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. Customer living in City Naypyitaw has done maximum payment.
# 2. Customer living in City Mandalay has done minimum payment.

# %%
Yangon_City_df=new_df[new_df['City']=="Yangon"]

# %%
Yangon_City_df
# Out:
#     Branch    City            Product line  Unit price  Quantity   Tax 5%  \
# 0        A  Yangon       Health and beauty       74.69         7  26.1415
# 2        A  Yangon      Home and lifestyle       46.33         7  16.2155
# 3        A  Yangon       Health and beauty       58.22         8  23.2880
# 4        A  Yangon       Sports and travel       86.31         7  30.2085
# 6        A  Yangon  Electronic accessories       68.84         6  20.6520
# ..     ...     ...                     ...         ...       ...      ...
# 990      A  Yangon      Food and beverages       56.56         5  14.1400
# 992      A  Yangon  Electronic accessories       58.03         2   5.8030
# 997      A  Yangon      Food and beverages       31.84         1   1.5920
# 998      A  Yangon      Home and lifestyle       65.82         1   3.2910
# 999      A  Yangon     Fashion accessories       88.34         7  30.9190
#
#         Total
# 0    548.9715
# 2    340.5255
# 3    489.0480
# 4    634.3785
# ...

# %%
sns.barplot(x=Yangon_City_df['Product line'],y=Yangon_City_df['Total'])
plt.xticks(rotation=90)
plt.show()

# %%
Yangon_City_df.groupby("Product line")['Total'].mean().sort_values(ascending=False)
# Out:
# Product line
# Home and lifestyle        344.879931
# Sports and travel         328.350839
# Fashion accessories       305.864370
# Electronic accessories    305.285225
# Food and beverages        295.915526
# Health and beauty         268.037298
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. Customer has done maximum Payment for Home and lifestyle and minimum Payment for Health and beauty for Yangon City

# %%
branch_B_df=new_df[new_df['Branch']=="B"]

# %%
branch_B_df
# Out:
#     Branch      City            Product line  Unit price  Quantity  Tax 5%  \
# 9        B  Mandalay      Food and beverages       54.84         3   8.226
# 10       B  Mandalay     Fashion accessories       14.48         4   2.896
# 11       B  Mandalay  Electronic accessories       25.51         4   5.102
# 15       B  Mandalay       Sports and travel       93.72         6  28.116
# 19       B  Mandalay      Home and lifestyle       40.30         2   4.030
# ..     ...       ...                     ...         ...       ...     ...
# 986      B  Mandalay       Health and beauty       14.76         2   1.476
# 987      B  Mandalay       Health and beauty       62.00         8  24.800
# 989      B  Mandalay       Health and beauty       75.37         8  30.148
# 991      B  Mandalay       Sports and travel       76.60        10  38.300
# 993      B  Mandalay     Fashion accessories       17.49        10   8.745
#
#        Total
# 9    172.746
# 10    60.816
# 11   107.142
# ...

# %%
sns.barplot(x=branch_B_df['Product line'],y=branch_B_df['Total'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df.groupby("Product line")['Total'].mean().sort_values(ascending=False)
# Out:
# Product line
# Sports and travel         328.004282
# Health and beauty         323.643020
# Electronic accessories    319.632538
# Home and lifestyle        319.164731
# Food and beverages        318.557133
# Fashion accessories       292.590000
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. Customer has done maximum Payment for Sports and travel and minimum Payment for Fashion accessories for branch  B.

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
df['Month'].value_counts()
# Out:
# 1    347
# 3    344
# 2    300
# Name: Month, dtype: int64

# %%
new_df=df[['Branch','City','Payment','Tax 5%','Total','Rating','Month','Year']]

# %%
new_df
# Out:
#     Branch       City      Payment   Tax 5%     Total  Rating  Month  Year
# 0        A     Yangon      Ewallet  26.1415  548.9715     9.1      1  2019
# 1        C  Naypyitaw         Cash   3.8200   80.2200     9.6      3  2019
# 2        A     Yangon  Credit card  16.2155  340.5255     7.4      3  2019
# 3        A     Yangon      Ewallet  23.2880  489.0480     8.4      1  2019
# 4        A     Yangon      Ewallet  30.2085  634.3785     5.3      2  2019
# ..     ...        ...          ...      ...       ...     ...    ...   ...
# 994      C  Naypyitaw      Ewallet   3.0475   63.9975     5.9      2  2019
# 995      C  Naypyitaw      Ewallet   2.0175   42.3675     6.2      1  2019
# 997      A     Yangon         Cash   1.5920   33.4320     7.7      2  2019
# 998      A     Yangon         Cash   3.2910   69.1110     4.1      2  2019
# 999      A     Yangon         Cash  30.9190  649.2990     6.6      2  2019
#
# [991 rows x 8 columns]

# %%
sns.countplot(x=new_df['Payment'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
new_df.groupby("Payment").size()
# Out:
# Payment
# Cash           342
# Credit card    307
# Ewallet        342
# dtype: int64

# %% [markdown]
# # Observations:
# 1. Customer has done maximum Cash Payment and Ewallet Payment and minimum Credit card Payment.

# %%
sns.countplot(x=new_df['Payment'],hue=new_df['Month'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %%
new_df.groupby(["Payment","Month"]).size().sort_values(ascending=False)
# Out:
# Payment      Month
# Ewallet      3        126
# Cash         1        120
# Ewallet      1        115
# Cash         2        112
# Credit card  1        112
# Cash         3        110
# Credit card  3        108
# Ewallet      2        101
# Credit card  2         87
# dtype: int64

# %% [markdown]
# # Observations:
# 1. Customer has done maximum payment using Ewallet for Month 3.
# 2. Customer has done minimum payment using Credit card for Month 2.

# %%
sns.countplot(x=new_df['Branch'],hue=new_df['Payment'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='count'>

# %%
new_df.groupby(["Branch","Payment"]).size().sort_values(ascending=False)
# Out:
# Branch  Payment
# A       Ewallet        126
# C       Cash           122
# B       Ewallet        112
# A       Cash           110
# B       Cash           110
#         Credit card    108
# C       Ewallet        104
# A       Credit card    103
# C       Credit card     96
# dtype: int64

# %% [markdown]
# # Observations:
# 1. Maximum payment is done at Branch A using Ewallet Payment.
# 2. Minimum payment is done at Branch C using Credit Card Payment.

# %%
sns.barplot(x=new_df['Branch'],y=new_df['Total'],hue=new_df['Month'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Total'>

# %%
new_df.groupby(["Branch","Month"])['Total'].mean().sort_values(ascending=False)
# Out:
# Branch  Month
# C       3        350.934368
# B       1        328.669759
# A       1        325.051500
# B       2        315.819000
# C       2        315.016607
# A       2        309.901403
# C       1        308.226788
# B       3        302.476149
# A       3        296.528516
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. In month 3 customer has done maximum average payment at Branch C of month 3.
# 2. In month 3 customer has done minimum average payment at Branch A of month 3.

# %%
sns.barplot(x=new_df['Payment'],y=new_df['Total'],hue=new_df['Month'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
new_df.groupby(["Payment","Month"])['Total'].mean().sort_values(ascending=False)
# Out:
# Payment      Month
# Ewallet      3        337.955500
# Credit card  1        332.358844
# Cash         1        331.369763
# Credit card  2        324.797466
# Cash         2        319.163719
#              3        315.365018
# Ewallet      2        298.148644
#              1        297.539139
# Credit card  3        288.522889
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. In month 3 , maximum average rating is done in month 3 using Ewallet
# 2. In month 3 , minimum average rating is done in month 3 using Credit card

# %%
sns.barplot(x=new_df['Branch'],y=new_df['Rating'],hue=new_df['Month'])
# Out:
# <AxesSubplot:xlabel='Branch', ylabel='Rating'>

# %%
new_df.groupby(["Branch","Month"])['Rating'].mean()
# Out:
# Branch  Month
# A       1        7.078151
#         2        6.989247
#         3        6.993701
# B       1        6.819091
#         2        7.008257
#         3        6.669369
# C       1        7.206780
#         2        7.190816
#         3        6.858491
# Name: Rating, dtype: float64

# %% [markdown]
# # Observations:
# 1. In month 1 , Branch C has maximum average rating.
# 2. In month 2 , Branch C has maximum average rating.
# 3. In month 3 , Branch A has maximum average rating.

# %%
new_df=new_df[new_df['City']=="Yangon"]

# %%
new_df
# Out:
#     Branch    City      Payment   Tax 5%     Total  Rating  Month  Year
# 0        A  Yangon      Ewallet  26.1415  548.9715     9.1      1  2019
# 2        A  Yangon  Credit card  16.2155  340.5255     7.4      3  2019
# 3        A  Yangon      Ewallet  23.2880  489.0480     8.4      1  2019
# 4        A  Yangon      Ewallet  30.2085  634.3785     5.3      2  2019
# 6        A  Yangon      Ewallet  20.6520  433.6920     5.8      2  2019
# ..     ...     ...          ...      ...       ...     ...    ...   ...
# 990      A  Yangon  Credit card  14.1400  296.9400     4.5      3  2019
# 992      A  Yangon      Ewallet   5.8030  121.8630     8.8      3  2019
# 997      A  Yangon         Cash   1.5920   33.4320     7.7      2  2019
# 998      A  Yangon         Cash   3.2910   69.1110     4.1      2  2019
# 999      A  Yangon         Cash  30.9190  649.2990     6.6      2  2019
#
# [339 rows x 8 columns]

# %%
sns.countplot(x=new_df['Payment'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='count'>

# %% [markdown]
# # Observation :
# 1. Maximum total payments are done from Ewallet in Yangon City.
# 2. Minimum total payments are done from  Credit Card in Yangon City.

# %%
sns.barplot(x=new_df['Payment'],y=new_df['Total'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
new_df.groupby("Payment")['Total'].mean()
# Out:
# Payment
# Cash           307.102282
# Credit card    311.218063
# Ewallet        312.098167
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maximum average payments are done from Ewallet in Yangon City.
# 2. Minimum average payments are done from  Cash in Yangon City.

# %%
sns.barplot(x=new_df['Payment'],y=new_df['Total'],hue=new_df['Month'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
new_df.groupby(["Payment","Month"])['Total'].mean().sort_values(ascending=False)
# Out:
# Payment      Month
# Credit card  1        355.636853
# Cash         2        334.261922
# Ewallet      3        330.304435
#              1        316.061413
# Credit card  2        316.033667
# Cash         1        308.991038
#              3        282.928692
# Ewallet      2        282.104118
# Credit card  3        272.164250
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maximum average payments are done in month 1 from credit card in Yangon City.
# 2. Minimum average payments are done in month 3 from credit card in Yangon City.

# %%
sns.barplot(x=new_df['Payment'],y=new_df['Rating'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Rating'>

# %%
new_df.groupby("Payment")['Rating'].mean().sort_values(ascending=False)
# Out:
# Payment
# Ewallet        7.138889
# Credit card    6.968932
# Cash           6.938182
# Name: Rating, dtype: float64

# %% [markdown]
# # Observation :
# 1. Payment done by customer using Ewallet has given maximum rating from Yangon City.
# 2. Payment done by customer using Cash has given minimum rating from Yangon City.

# %%
sns.barplot(x=new_df['Payment'],y=new_df['Rating'],hue=new_df['Month'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Rating'>

# %%
new_df.groupby(["Payment","Month"])['Rating'].mean().sort_values(ascending=False)
# Out:
# Payment      Month
# Credit card  1        7.264706
# Ewallet      2        7.229412
#              1        7.219565
# Cash         3        7.171795
# Ewallet      3        6.991304
# Cash         2        6.884375
# Credit card  3        6.830952
#              2        6.811111
# Cash         1        6.748718
# Name: Rating, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maxium rating is given by customers in the month of 1 who do payments from credit card from Yangon City.
# 2. Minimum rating is given by customers in the month of 1 who do payments from cash from Yangon City.

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
new_df=df[['Customer type','Gender','Hour','Minute','Month','Day','Total','Payment']]

# %%
new_df
# Out:
#     Customer type  Gender  Hour  Minute  Month  Day     Total      Payment
# 0          Member  Female    13       8      1    5  548.9715      Ewallet
# 1          Normal  Female    10      29      3    8   80.2200         Cash
# 2          Normal    Male    13      23      3    3  340.5255  Credit card
# 3          Member    Male    20      33      1   27  489.0480      Ewallet
# 4          Normal    Male    10      37      2    8  634.3785      Ewallet
# ..            ...     ...   ...     ...    ...  ...       ...          ...
# 994        Member  Female    11      40      2   18   63.9975      Ewallet
# 995        Normal    Male    13      46      1   29   42.3675      Ewallet
# 997        Member    Male    13      22      2    9   33.4320         Cash
# 998        Normal    Male    15      33      2   22   69.1110         Cash
# 999        Member  Female    13      28      2   18  649.2990         Cash
#
# [991 rows x 8 columns]

# %%
sns.barplot(x=new_df['Customer type'],y=new_df['Total'])
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='Total'>

# %%
new_df.groupby("Customer type")['Total'].mean().sort_values(ascending=False)
# Out:
# Customer type
# Member    323.545440
# Normal    309.593671
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Member customers do maximum average payments as comapred to Normal customers.

# %%
sns.barplot(x=new_df['Customer type'],y=new_df['Total'],hue=new_df['Gender'])
# Out:
# <AxesSubplot:xlabel='Customer type', ylabel='Total'>

# %%
new_df.groupby(["Customer type","Gender"])['Total'].mean().sort_values(ascending=False)
# Out:
# Customer type  Gender
# Member         Female    329.647785
# Normal         Female    323.582222
# Member         Male      316.985419
# Normal         Male      296.643334
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Female member customers do maximum average payments.
# 2. Male member customers do minimum average payments.

# %%
sns.barplot(x=new_df['Payment'],y=new_df['Total'],hue=new_df['Gender'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
new_df.groupby(["Payment","Gender"])['Total'].mean().sort_values(ascending=False)
# Out:
# Payment      Gender
# Ewallet      Female    334.261519
# Cash         Female    330.576780
# Credit card  Female    315.079406
#              Male      314.485286
# Cash         Male      313.265273
# Ewallet      Male      294.016777
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Female customers do maximum average payments from Ewallet.
# 2. Male customers do minimum average payments from Ewallet.

# %%
sns.barplot(x=new_df['Payment'],y=new_df['Total'],hue=new_df['Month'])
# Out:
# <AxesSubplot:xlabel='Payment', ylabel='Total'>

# %%
new_df.groupby(["Payment","Month"])['Total'].mean().sort_values(ascending=False)
# Out:
# Payment      Month
# Ewallet      3        337.955500
# Credit card  1        332.358844
# Cash         1        331.369763
# Credit card  2        324.797466
# Cash         2        319.163719
#              3        315.365018
# Ewallet      2        298.148644
#              1        297.539139
# Credit card  3        288.522889
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maximum average payments are done by Ewallet in the month of 3.
# 2. Minimum average payments are done by Credit card in the month of 3.

# %%
plt.figure(figsize=(15,10))
sns.barplot(x=new_df['Day'],y=new_df['Total'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df.groupby("Day")['Total'].mean().sort_values(ascending=False)
# Out:
# Day
# 29    376.990425
# 31    373.749750
# 19    363.005744
# 12    361.251800
# 11    356.235833
# 9     354.587917
# 27    352.583368
# 24    351.575000
# 1     350.860125
# 14    349.624154
# 17    347.287150
# 23    345.244958
# 3     344.423042
# 16    343.989692
# 20    337.716300
# 15    325.057750
# 30    316.361132
# 5     312.163207
# 28    310.871050
# 10    308.287547
# 7     302.650342
# 2     298.058115
# 8     293.430308
# 6     291.279545
# 21    283.167675
# 25    280.489750
# 4     274.400845
# 22    261.651000
# 18    242.145065
# 26    226.363846
# 13    194.608875
# Name: Total, dtype: float64

# %% [markdown]
# # Observation :
# 1. Maximum average payment is done on day 29.
# 2. Minimum average payment is done on day 13.

# %%
plt.figure(figsize=(15,15))
sns.barplot(x=new_df['Day'],y=new_df['Total'],hue=new_df['Payment'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Observation :
# 1. Maximum average payment done by Credit Card on 9th Day

# %%
new_df
# Out:
#     Customer type  Gender  Hour  Minute  Month  Day     Total      Payment
# 0          Member  Female    13       8      1    5  548.9715      Ewallet
# 1          Normal  Female    10      29      3    8   80.2200         Cash
# 2          Normal    Male    13      23      3    3  340.5255  Credit card
# 3          Member    Male    20      33      1   27  489.0480      Ewallet
# 4          Normal    Male    10      37      2    8  634.3785      Ewallet
# ..            ...     ...   ...     ...    ...  ...       ...          ...
# 994        Member  Female    11      40      2   18   63.9975      Ewallet
# 995        Normal    Male    13      46      1   29   42.3675      Ewallet
# 997        Member    Male    13      22      2    9   33.4320         Cash
# 998        Normal    Male    15      33      2   22   69.1110         Cash
# 999        Member  Female    13      28      2   18  649.2990         Cash
#
# [991 rows x 8 columns]

# %%
sns.countplot(x=new_df['Hour'],hue=new_df['Payment'])
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='count'>

# %% [markdown]
# # Observation :
# 1. Maximum average payments are done by Ewallet at 19 hours of day
# 2. Maximum average payments are done by Ewallet at 17 hours of day

# %%
sns.countplot(x=new_df['Hour'],hue=new_df['Gender'])
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='count'>

# %%
new_df.groupby(["Hour","Gender"]).size().sort_values(ascending=False)
# Out:
# Hour  Gender
# 10    Female    62
# 15    Male      60
# 19    Male      59
# 13    Female    58
# 19    Female    54
# 18    Male      48
# 11    Female    47
# 12    Female    46
# 18    Female    45
# 20    Male      44
# 14    Male      44
# 11    Male      43
# 12    Male      43
# 15    Female    42
# 13    Male      41
# 10    Male      39
# 16    Male      39
# 14    Female    38
# 17    Female    37
#       Male      36
# 16    Female    36
# 20    Female    30
# dtype: int64

# %% [markdown]
# # Observation :
# 1. Maximum female customers do shopping at 10 hour.
# 2. Minimum female customers do shopping at 20 hour.

# %%
sns.countplot(x=new_df['Hour'],hue=new_df['Customer type'])
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='count'>

# %%
new_df.groupby(["Hour","Customer type"]).size().sort_values(ascending=False)
# Out:
# Hour  Customer type
# 19    Member           61
# 10    Normal           59
# 15    Member           56
# 19    Normal           52
# 13    Normal           51
#       Member           48
# 18    Normal           48
# 14    Member           47
# 15    Normal           46
# 11    Member           46
# 12    Member           46
# 18    Member           45
# 11    Normal           44
# 12    Normal           43
# 10    Member           42
# 20    Normal           40
# 16    Normal           38
# 17    Normal           37
# 16    Member           37
# 17    Member           36
# 14    Normal           35
# 20    Member           34
# dtype: int64

# %% [markdown]
# # Observation :
# 1. Maximum normal customer type normal do shopping at 19 hour.
# 2. Minimum member customer type normal do shopping at 20 hour.

# %%
sns.barplot(x=new_df['Hour'],y=new_df['Total'],hue=new_df['Payment'])
# Out:
# <AxesSubplot:xlabel='Hour', ylabel='Total'>

# %%
new_df.groupby(["Hour","Payment"])['Total'].mean().sort_values(ascending=False)
# Out:
# Hour  Payment
# 14    Credit card    406.629125
# 20    Cash           382.437391
# 19    Ewallet        374.436250
# 11    Cash           370.102456
# 19    Credit card    368.411167
# 10    Cash           367.158346
# 15    Credit card    364.586950
# 16    Ewallet        355.335750
# 14    Cash           348.845389
# 11    Credit card    346.427340
# 17    Ewallet        342.492706
# 14    Ewallet        342.187887
# 10    Ewallet        340.858389
# 13    Cash           332.724000
# 17    Credit card    326.975444
# 12    Credit card    320.022500
#       Cash           319.095724
# 19    Cash           306.011100
# 13    Ewallet        305.042500
# 17    Cash           302.483276
# 18    Credit card    299.417323
# 11    Ewallet        294.618145
# 15    Ewallet        291.500149
# 13    Credit card    281.975400
# 18    Ewallet        277.786359
# 16    Cash           277.738696
#       Credit card    270.227475
# 15    Cash           270.182700
# ...

# %% [markdown]
# # Observation :
# 1. Maximum customers do shopping at 14 hour using credit card.
# 2. Minimum customers do shopping at 10 hour using credit card.

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
new_df=df[['Gender','Product line','Total','Payment','Hour','Minute','Day','Year']]

# %%
new_df
# Out:
#      Gender            Product line     Total      Payment  Hour  Minute  Day  \
# 0    Female       Health and beauty  548.9715      Ewallet    13       8    5
# 1    Female  Electronic accessories   80.2200         Cash    10      29    8
# 2      Male      Home and lifestyle  340.5255  Credit card    13      23    3
# 3      Male       Health and beauty  489.0480      Ewallet    20      33   27
# 4      Male       Sports and travel  634.3785      Ewallet    10      37    8
# ..      ...                     ...       ...          ...   ...     ...  ...
# 994  Female  Electronic accessories   63.9975      Ewallet    11      40   18
# 995    Male       Health and beauty   42.3675      Ewallet    13      46   29
# 997    Male      Food and beverages   33.4320         Cash    13      22    9
# 998    Male      Home and lifestyle   69.1110         Cash    15      33   22
# 999  Female     Fashion accessories  649.2990         Cash    13      28   18
#
#      Year
# 0    2019
# ...

# %%
sns.barplot(x=new_df['Product line'],y=new_df['Total'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df.groupby("Product line")['Total'].mean().sort_values(ascending=False)
# Out:
# Product line
# Sports and travel         328.004282
# Health and beauty         323.643020
# Electronic accessories    319.632538
# Home and lifestyle        319.164731
# Food and beverages        318.557133
# Fashion accessories       292.590000
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. Minimum amount spend by customer on Fashion accessories.
# 2. Maximum amount spend by customer on Sports and travel.

# %%
sns.barplot(x=new_df['Product line'],y=new_df['Total'],hue=new_df['Gender'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df.groupby(["Product line","Gender"])['Total'].mean().sort_values(ascending=False)
# Out:
# Product line            Gender
# Home and lifestyle      Female    363.532500
# Food and beverages      Female    361.083792
# Health and beauty       Male      348.099460
# Sports and travel       Male      340.360327
# Electronic accessories  Female    322.643125
# Sports and travel       Female    316.926448
# Electronic accessories  Male      316.691965
# Fashion accessories     Female    301.851543
# Health and beauty       Female    290.015414
# Fashion accessories     Male      281.842037
# Home and lifestyle      Male      275.920196
# Food and beverages      Male      273.499125
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. Female customer spend maximum avg amount on Home and lifestyle.
# 2. male customer spend minimum avg amount on Food and beverages.

# %%
sns.barplot(x=new_df['Hour'],y=new_df['Total'],hue=new_df['Gender'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df.groupby(["Hour","Gender"])['Total'].mean().sort_values(ascending=False)
# Out:
# Hour  Gender
# 14    Male      382.286864
# 19    Female    372.439278
# 16    Female    366.420833
# 10    Male      358.156077
# 11    Female    355.378085
# 13    Female    348.028112
# 14    Female    341.187553
# 15    Female    339.569000
# 19    Male      331.996475
# 20    Female    327.876150
# 17    Female    327.826459
# 11    Male      318.013012
# 17    Male      313.698583
# 18    Male      303.804812
# 12    Male      293.326291
#       Female    292.453304
# 15    Male      281.960175
# 10    Female    281.506355
# 20    Male      274.972330
# 13    Male      255.824305
# 16    Male      255.695731
# 18    Female    254.393533
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. Male customer spend maximum avg amount at 14 Hour.
# 1. Female customer spend minimum avg amount at 18 Hour.

# %%
sns.barplot(x=new_df['Product line'],y=new_df['Total'],hue=new_df['Payment'])
plt.xticks(rotation=90)
plt.show()

# %%
new_df.groupby(["Product line","Payment"])['Total'].mean().sort_values(ascending=False)
# Out:
# Product line            Payment
# Home and lifestyle      Cash           351.708210
# Health and beauty       Cash           350.798143
# Electronic accessories  Ewallet        343.010038
# Sports and travel       Ewallet        341.347417
# Food and beverages      Cash           337.032868
# Sports and travel       Credit card    336.155717
# Electronic accessories  Credit card    335.391685
# Food and beverages      Credit card    331.724434
# Health and beauty       Credit card    319.389420
# Home and lifestyle      Ewallet        310.380677
# Fashion accessories     Cash           309.013895
# Sports and travel       Cash           308.132638
# Health and beauty       Ewallet        302.550170
# Fashion accessories     Ewallet        297.800515
# Home and lifestyle      Credit card    294.561034
# Electronic accessories  Cash           291.971577
# Food and beverages      Ewallet        284.805818
# Fashion accessories     Credit card    268.536311
# Name: Total, dtype: float64

# %% [markdown]
# # Observations:
# 1. Customer spend maximum avg amount on Home and lifestyle and payment is done using Cash.
# 2. Customer spend minimum avg amount on Fashion accessories and payment is done using Credit card.

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 994      C  Naypyitaw        Member  Female  Electronic accessories
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%     Total      Payment    cogs  \
# 0         74.69         7  26.1415  548.9715      Ewallet  522.83
# ...

# %%
Product_line_tax_branch_df=df[['Tax 5%','Branch','Product line']]

# %%
Product_line_tax_branch_df
# Out:
#       Tax 5% Branch            Product line
# 0    26.1415      A       Health and beauty
# 1     3.8200      C  Electronic accessories
# 2    16.2155      A      Home and lifestyle
# 3    23.2880      A       Health and beauty
# 4    30.2085      A       Sports and travel
# ..       ...    ...                     ...
# 994   3.0475      C  Electronic accessories
# 995   2.0175      C       Health and beauty
# 997   1.5920      A      Food and beverages
# 998   3.2910      A      Home and lifestyle
# 999  30.9190      A     Fashion accessories
#
# [991 rows x 3 columns]

# %%
Product_line_tax_branch_df=Product_line_tax_branch_df.sort_values(by="Tax 5%",ascending=False)

# %%
Product_line_tax_branch_df
# Out:
#       Tax 5% Branch         Product line
# 429  45.3250      A   Home and lifestyle
# 141  45.2500      C    Health and beauty
# 122  44.9820      B    Sports and travel
# 941  44.9190      C  Fashion accessories
# 140  44.9000      C    Sports and travel
# ..       ...    ...                  ...
# 402   0.6990      C   Home and lifestyle
# 443   0.6390      C  Fashion accessories
# 223   0.6270      C  Fashion accessories
# 629   0.6045      A  Fashion accessories
# 822   0.5085      C    Sports and travel
#
# [991 rows x 3 columns]

# %%
sns.barplot(x=Product_line_tax_branch_df['Product line'],y=Product_line_tax_branch_df['Tax 5%'])
plt.xticks(rotation=90)
plt.show()

# %%
Product_line_tax_branch_df.groupby("Product line")['Tax 5%'].mean().sort_values(ascending=False)
# Out:
# Product line
# Sports and travel         15.619252
# Health and beauty         15.411572
# Electronic accessories    15.220597
# Home and lifestyle        15.198321
# Food and beverages        15.169387
# Fashion accessories       13.932857
# Name: Tax 5%, dtype: float64

# %% [markdown]
# # Observations:
# 1. Customer give maximum Tax 5% for Sports and travel.
# 2. Customer give minimum Tax 5% for Fashion accessories.

# %%
sns.barplot(x=Product_line_tax_branch_df['Product line'],y=Product_line_tax_branch_df['Tax 5%'],hue=Product_line_tax_branch_df['Branch'])
plt.xticks(rotation=90)
plt.show()

# %%
Product_line_tax_branch_df.groupby(["Product line","Branch"])['Tax 5%'].mean().sort_values(ascending=False)
# Out:
# Product line            Branch
# Health and beauty       B         17.952075
# Food and beverages      C         16.653769
# Electronic accessories  C         16.423355
# Home and lifestyle      A         16.422854
# Sports and travel       C         15.973818
#                         A         15.635754
# Home and lifestyle      B         15.381240
# Sports and travel       B         15.351919
# Health and beauty       C         15.215500
# Electronic accessories  B         14.763155
# Fashion accessories     C         14.736746
#                         A         14.564970
# Electronic accessories  A         14.537392
# Food and beverages      B         14.490370
#                         A         14.091216
# Home and lifestyle      C         13.143093
# Health and beauty       A         12.763681
# Fashion accessories     B         12.606234
# Name: Tax 5%, dtype: float64

# %% [markdown]
# # Observations:
# 1. Customer give maximum Tax 5% for Health and beauty at Branch B.
# 2. Customer give minimum Tax 5% for Fashion accessories at Branch B.
